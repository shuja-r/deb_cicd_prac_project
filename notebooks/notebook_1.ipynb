# %%
print("this is notebook1")
# Out:
# this is notebook1

# %%
spark.sql("SELECT 1").show()
# Out:
# +---+
# |  1|
# +---+
# |  1|
# +---+

# %%
import os
import sys
current_dir=os.getcwd()
var=os.path.join(current_dir,"..")
print(current_dir)
print(var)
project_root=os.path.abspath(os.path.join(current_dir,".."))
print(project_root)
# sys.path.append(project_root)
#sys.path.pop()
# print(sys.path)
# print(os.path)
# Out:
# e:\Databricks\Databricks_CICD_Practice\deb_cicd_prac_project\notebooks
# e:\Databricks\Databricks_CICD_Practice\deb_cicd_prac_project\notebooks\..
# e:\Databricks\Databricks_CICD_Practice\deb_cicd_prac_project
# ...
